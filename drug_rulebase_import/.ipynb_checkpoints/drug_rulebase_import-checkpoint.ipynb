# %%
import pandas as pd 
import numpy as np
from py2neo import Graph, Node, Relationship, authenticate


def createDrugs(graph,data):
    uniqueDrugs = np.unique(data["drug"])
    print uniqueDrugs
    nodeCount = 0
    for drug in uniqueDrugs:
        graph.cypher.execute("MERGE (d:Drug {{name:\"{0}\"}})".format(drug))
        nodeCount = nodeCount + 1

def createGenes(graph,data):
    for row_index, row in data.iterrows():
        gene_name = ""
        gene_entrez = ""
        if row["entity_class"] == "biomarker":
            gene_name = row["biomarker_symbol"]
            gene_entrez = row["biomarker_entrez"]
        elif row["entity_class"] == "modifier":
            gene_name = row["modifier_symbol"]
            gene_entrez = row["modifier_entrez"]
        else:
            print"Error in getting genes"
            break
        query = (
            "MATCH (d:Drug {{ name:'{2}'}}) "
            "MERGE (g:Gene {{ name:'{0}', entrez:'{1}'}}) "
            "CREATE UNIQUE (d)-[:TARGETS]->(g) "
        ).format(gene_name, gene_entrez, row["drug"])
        print query
        graph.cypher.execute(query)

def createAberrations(graph,data):
    for row_index, row in data.iterrows():
        gene_name = ""
        gene_entrez = ""
        ab_type = ""
        ab_value = ""
        
        if row["entity_class"] == "biomarker":
            gene_name = row["biomarker_symbol"]
            gene_entrez = row["biomarker_entrez"]
            ab_type = row["biomarker_aberration_type"]
            ab_value = row["biomarker_aberration_value"]
            
        elif row["entity_class"] == "modifier":
            gene_name = row["modifier_symbol"]
            gene_entrez = row["modifier_entrez"]
            ab_type = row["modifier_aberration_type"]
            ab_value = row["modifier_aberration_value"]
        else:
            print"Error in createAberrations()"
            break
            
        query = ("MATCH (g:Gene {{name:'{0}', entrez:'{1}'}}), (d:Drug {{name:'{6}'}}) "
                "MERGE (a:Aberration {{ type:'{2}', value:'{3}', gene_entrez:'{4}', entity_class:'{5}' }}) "
                "CREATE UNIQUE (g)-[:HAS_ABERRATION]->(a) "
                "CREATE UNIQUE (d)-[:TARGETS]->(a)"
                ).format(gene_name, gene_entrez, ab_type, ab_value, gene_entrez, row["entity_class"], row["drug"])
        print query
        graph.cypher.execute(query)
    
def createRuleNodes(graph,data):
    for row_index, row in data.iterrows():
        gene_name = ""
        gene_entrez = ""
        ab_type = ""
        ab_value = ""
        
        if row["entity_class"] == "biomarker":
            gene_name = row["biomarker_symbol"]
            gene_entrez = row["biomarker_entrez"]
            ab_type = row["biomarker_aberration_type"]
            ab_value = row["biomarker_aberration_value"]
            
        elif row["entity_class"] == "modifier":
            gene_name = row["modifier_symbol"]
            gene_entrez = row["modifier_entrez"]
            ab_type = row["modifier_aberration_type"]
            ab_value = row["modifier_aberration_value"]
        else:
            print"Error in createAberrations()"
            break
        query = ("MATCH (g:Gene {{name:'{0}', entrez:'{1}'}}), "
                 "(a:Aberration {{ type:'{2}', value:'{3}', gene_entrez:'{4}', entity_class:'{5}' }}), "
                 "(d:Drug {{name:'{6}'}} ) "
                 "Merge (r:Rule {{rulenum:'{7}', evidence:'{8}', pmid:'{9}', evidence_text:\"{10}\" }}) "
                 "CREATE UNIQUE (r)<-[:IS_PART_OF]-(g) "
                 "CREATE UNIQUE (r)<-[:IS_PART_OF]-(a) "
                 "CREATE UNIQUE (r)<-[:IS_PART_OF]-(d) "
                ).format(gene_name, gene_entrez, ab_type, ab_value, gene_entrez, row["entity_class"], 
                         row["drug"], row_index, row["Evidence"], row["PMID"], row["Evidence Text"])
        print query
        graph.cypher.execute(query)
    
   
        
def main():
    print "Starting Main Function"
    data = pd.read_csv('DrugRulesFixed.csv')

    authenticate("localhost:7474", "neo4j", "qwerty1")
    graph = Graph()
    
    #createDrugs(graph,data)
    #createGenes(graph,data)
    #createAberrations(graph,data)
    createRuleNodes(graph,data)
main()
# Out:
# Starting Main Function
# ['AMG 337' 'Alisertib' 'Axitinib' 'BGJ398' 'GSK2141795' 'LEE011'
#  'LY2157299' 'MEK162' 'MLN0128' 'MLN1117' 'MLN2480' 'MLN9708' 'PF-00299804'
#  'PLX3397' 'Palbociclib' 'Trametinib' 'bortezomib' 'bosutinib'
#  'cabozantinib' 'carboplatin' 'crizotinib' 'dacarbazine' 'dasatinib'
#  'doxorubicin' 'erlotinib' 'etoposide' 'gemcitabine' 'imatinib'
#  'paclitaxel' 'pemetrexed' 'sorafenib' 'sunitinib' 'temozolomide'
#  'temsirolimus' 'vorinostat']
# MATCH (d:Drug { name:'Alisertib'}) MERGE (g:Gene { name:'AURKB', entrez:'9212'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'Alisertib'}) MERGE (g:Gene { name:'AURKB', entrez:'9212'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'Alisertib'}) MERGE (g:Gene { name:'AURKB', entrez:'9212'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'Alisertib'}) MERGE (g:Gene { name:'AURKB', entrez:'9212'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'Alisertib'}) MERGE (g:Gene { name:'AURKB', entrez:'9212'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'Alisertib'}) MERGE (g:Gene { name:'AURKB', entrez:'9212'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'Alisertib'}) MERGE (g:Gene { name:'HMMR', entrez:'3161'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'Alisertib'}) MERGE (g:Gene { name:'HMMR', entrez:'3161'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'Alisertib'}) MERGE (g:Gene { name:'AURKA', entrez:'6790'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'Alisertib'}) MERGE (g:Gene { name:'AURKA', entrez:'6790'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'Alisertib'}) MERGE (g:Gene { name:'AURKA', entrez:'6790'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'Alisertib'}) MERGE (g:Gene { name:'AURKA', entrez:'6790'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'Alisertib'}) MERGE (g:Gene { name:'AURKA', entrez:'6790'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'Alisertib'}) MERGE (g:Gene { name:'AURKB', entrez:'9212'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'EGFR', entrez:'1956'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'EGFR', entrez:'1956'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'EGFR', entrez:'1956'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'ERBB3', entrez:'2065'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'ERBB3', entrez:'2065'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'KRAS', entrez:'3845'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'KRAS', entrez:'3845'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'AMG 337'}) MERGE (g:Gene { name:'TGFA', entrez:'7039'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'Axitinib'}) MERGE (g:Gene { name:'PDGFRB', entrez:'5159'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'Axitinib'}) MERGE (g:Gene { name:'PDGFRB', entrez:'5159'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'Axitinib'}) MERGE (g:Gene { name:'PDGFRB', entrez:'5159'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'Axitinib'}) MERGE (g:Gene { name:'PDGFRA', entrez:'5156'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'Axitinib'}) MERGE (g:Gene { name:'PDGFRA', entrez:'5156'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'Axitinib'}) MERGE (g:Gene { name:'PDGFRA', entrez:'5156'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'Axitinib'}) MERGE (g:Gene { name:'KIT', entrez:'3815'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'Axitinib'}) MERGE (g:Gene { name:'KIT', entrez:'3815'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'Axitinib'}) MERGE (g:Gene { name:'KIT', entrez:'3815'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'Axitinib'}) MERGE (g:Gene { name:'KDR', entrez:'3791'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'Axitinib'}) MERGE (g:Gene { name:'KDR', entrez:'3791'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'Axitinib'}) MERGE (g:Gene { name:'KDR', entrez:'3791'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'Axitinib'}) MERGE (g:Gene { name:'FLT4', entrez:'2324'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'Axitinib'}) MERGE (g:Gene { name:'FLT4', entrez:'2324'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'Axitinib'}) MERGE (g:Gene { name:'FLT4', entrez:'2324'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'Axitinib'}) MERGE (g:Gene { name:'FLT1', entrez:'2321'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'Axitinib'}) MERGE (g:Gene { name:'FLT1', entrez:'2321'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'Axitinib'}) MERGE (g:Gene { name:'FLT1', entrez:'2321'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'Axitinib'}) MERGE (g:Gene { name:'RET', entrez:'5979'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'Axitinib'}) MERGE (g:Gene { name:'RET', entrez:'5979'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'Axitinib'}) MERGE (g:Gene { name:'RET', entrez:'5979'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'Axitinib'}) MERGE (g:Gene { name:'RET', entrez:'5979'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'Axitinib'}) MERGE (g:Gene { name:'RET', entrez:'5979'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'Axitinib'}) MERGE (g:Gene { name:'RET', entrez:'5979'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'Axitinib'}) MERGE (g:Gene { name:'ABCB1', entrez:'5243'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'Axitinib'}) MERGE (g:Gene { name:'ABCB1', entrez:'5243'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'Axitinib'}) MERGE (g:Gene { name:'ABCG2', entrez:'9429'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'Axitinib'}) MERGE (g:Gene { name:'ABCG2', entrez:'9429'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'Axitinib'}) MERGE (g:Gene { name:'ABL1', entrez:'25'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'Axitinib'}) MERGE (g:Gene { name:'ABL1', entrez:'25'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR3', entrez:'2261'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR3', entrez:'2261'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR3', entrez:'2261'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR3', entrez:'2261'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR3', entrez:'2261'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR3', entrez:'2261'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR3', entrez:'2261'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR3', entrez:'2261'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR3', entrez:'2261'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR3', entrez:'2261'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR3', entrez:'2261'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR3', entrez:'2261'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR2', entrez:'2263'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR1', entrez:'2260'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR1', entrez:'2260'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR1', entrez:'2260'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGFR1', entrez:'2260'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGF19', entrez:'9965'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FRS2', entrez:'10818'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FRS2', entrez:'10818'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGF2', entrez:'2247'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'FGF9', entrez:'2254'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'CDH1', entrez:'999'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'CDH13', entrez:'1012'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'NRG1', entrez:'3084'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'ERBB3', entrez:'2065'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'ERBB3', entrez:'2065'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'CDH1', entrez:'999'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'CDH13', entrez:'1012'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'NRG1', entrez:'3084'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'ERBB2', entrez:'2064'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'ERBB2', entrez:'2064'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'BGJ398'}) MERGE (g:Gene { name:'KRAS', entrez:'3845'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'PSMD4', entrez:'5710'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'PSMD4', entrez:'5710'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'PSMB8', entrez:'5696'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'PSMB8', entrez:'5696'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'PSMB5', entrez:'5693'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'PSMB5', entrez:'5693'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'PSMB5', entrez:'5693'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'PSMB5', entrez:'5693'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'PSMB5', entrez:'5693'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'PSMB5', entrez:'5693'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'PSMB5', entrez:'5693'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'PSMB5', entrez:'5693'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'PSMB5', entrez:'5693'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'PSMB5', entrez:'5693'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'PSMB5', entrez:'5693'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'PSMB5', entrez:'5693'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'PSMB5', entrez:'5693'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'PSMB5', entrez:'5693'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'PSMB5', entrez:'5693'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'PSMB5', entrez:'5693'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'PSMB5', entrez:'5693'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'PSMB5', entrez:'5693'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'PSMB5', entrez:'5693'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'HSPB1', entrez:'3315'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'HSPB1', entrez:'3315'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'HSPB2', entrez:'3316'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'HSPB2', entrez:'3316'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'TRAF3', entrez:'7187'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'TRAF3', entrez:'7187'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'FLT3', entrez:'2322'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'ATF4', entrez:'468'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'ATF4', entrez:'468'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'GPR78', entrez:'27201'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'GPR78', entrez:'27201'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'GNA12', entrez:'2768'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'GNA13', entrez:'10672'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'GNA12', entrez:'2768'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'GNA13', entrez:'10672'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'HSP90AA1', entrez:'3320'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'HSP90AA1', entrez:'3320'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'ATG7', entrez:'10533'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'ATG7', entrez:'10533'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'BECN1', entrez:'8678'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'BECN1', entrez:'8678'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'FGFR3', entrez:'2261'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'FGFR3', entrez:'2261'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'CDK5', entrez:'1020'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'CDK5', entrez:'1020'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'RRAD', entrez:'6236'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'RRAD', entrez:'6236'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'IGF1', entrez:'3479'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'IGF1', entrez:'3479'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'IGFR1', entrez:'443515'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'IGFR1', entrez:'443515'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'MIR33B', entrez:'693120'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'MIR33B', entrez:'693120'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'PIM1', entrez:'5292'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'PIM1', entrez:'5292'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'HSPA1B', entrez:'3304'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'HSPA1B', entrez:'3304'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'XBP1', entrez:'7494'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'XBP1', entrez:'7494'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'ERN1', entrez:'2081'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'ERN1', entrez:'2081'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'XBP1', entrez:'7494'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'XBP1', entrez:'7494'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'XBP1', entrez:'7494'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'XBP1', entrez:'7494'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'CCNE1', entrez:'898'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'CCNE1', entrez:'898'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'NRAS', entrez:'4893'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'NRAS', entrez:'4893'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'NRAS', entrez:'4893'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'NRAS', entrez:'4893'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'NRAS', entrez:'4893'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'NRAS', entrez:'4893'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'NRAS', entrez:'4893'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'NRAS', entrez:'4893'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'NRAS', entrez:'4893'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'NRAS', entrez:'4893'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'IGFR1', entrez:'443515'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'ATG7', entrez:'10533'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'BECN1', entrez:'8678'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'PIM1', entrez:'5292'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'NRAS', entrez:'4893'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'GNA12', entrez:'2768'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'GNA13', entrez:'10672'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'XBP1', entrez:'7494'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'ERN1', entrez:'2081'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'TRAF3', entrez:'7187'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'FGFR3', entrez:'2261'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bortezomib'}) MERGE (g:Gene { name:'CDK5', entrez:'1020'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'SRC', entrez:'6714'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'SRC', entrez:'6714'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'SRC', entrez:'6714'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'LYN', entrez:'4067'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'LYN', entrez:'4067'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'STK11', entrez:'6794'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'STK11', entrez:'6794'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'NEDD9', entrez:'4739'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'NEDD9', entrez:'4739'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'BTK', entrez:'695'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'BTK', entrez:'695'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'AXL', entrez:'558'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'AXL', entrez:'558'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'ABL1', entrez:'25'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'ABL1', entrez:'25'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'ABL1', entrez:'25'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'ABL1', entrez:'25'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'ABL1', entrez:'25'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'ABL1', entrez:'25'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'ABL1', entrez:'25'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'ABL1', entrez:'25'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'ABL1', entrez:'25'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'ABL1', entrez:'25'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'ABL1', entrez:'25'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'ABL1', entrez:'25'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'ABL1', entrez:'25'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'ABL1', entrez:'25'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'ABL1', entrez:'25'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'ABL1', entrez:'25'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'ABL1', entrez:'25'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'ABL1', entrez:'25'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'ABL1', entrez:'25'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'ABL1', entrez:'25'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'ABL1', entrez:'25'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'ABL1', entrez:'25'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'ABL1', entrez:'25'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'ABL1', entrez:'25'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'ABL1', entrez:'25'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'ABL1', entrez:'25'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'ABL1', entrez:'25'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'ABL1', entrez:'25'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'ABL1', entrez:'25'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'ABL1', entrez:'25'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'ABL1', entrez:'25'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'ABL1', entrez:'25'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'ABL1', entrez:'25'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'ABL1', entrez:'25'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'ABL1', entrez:'25'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'ABL1', entrez:'25'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'ABL1', entrez:'25'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'ABL1', entrez:'25'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'ABL1', entrez:'25'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'ABL1', entrez:'25'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'ABL1', entrez:'25'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'ABL1', entrez:'25'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'ABL1', entrez:'25'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'ABL1', entrez:'25'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'ABL1', entrez:'25'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'bosutinib'}) MERGE (g:Gene { name:'STK11', entrez:'6794'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'cabozantinib'}) MERGE (g:Gene { name:'TEK', entrez:'7010'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'cabozantinib'}) MERGE (g:Gene { name:'TEK', entrez:'7010'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'cabozantinib'}) MERGE (g:Gene { name:'TEK', entrez:'7010'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'cabozantinib'}) MERGE (g:Gene { name:'RET', entrez:'5979'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'cabozantinib'}) MERGE (g:Gene { name:'RET', entrez:'5979'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'cabozantinib'}) MERGE (g:Gene { name:'RET', entrez:'5979'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'cabozantinib'}) MERGE (g:Gene { name:'RET', entrez:'5979'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'cabozantinib'}) MERGE (g:Gene { name:'RET', entrez:'5979'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'cabozantinib'}) MERGE (g:Gene { name:'RET', entrez:'5979'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'cabozantinib'}) MERGE (g:Gene { name:'RET', entrez:'5979'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'cabozantinib'}) MERGE (g:Gene { name:'RET', entrez:'5979'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'cabozantinib'}) MERGE (g:Gene { name:'RET', entrez:'5979'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'cabozantinib'}) MERGE (g:Gene { name:'RET', entrez:'5979'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'cabozantinib'}) MERGE (g:Gene { name:'RET', entrez:'5979'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'cabozantinib'}) MERGE (g:Gene { name:'RET', entrez:'5979'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'cabozantinib'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'cabozantinib'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'cabozantinib'}) MERGE (g:Gene { name:'MET', entrez:'4233'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'cabozantinib'}) MERGE (g:Gene { name:'KIT', entrez:'3815'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'cabozantinib'}) MERGE (g:Gene { name:'KIT', entrez:'3815'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'cabozantinib'}) MERGE (g:Gene { name:'KIT', entrez:'3815'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'cabozantinib'}) MERGE (g:Gene { name:'KDR', entrez:'3791'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'cabozantinib'}) MERGE (g:Gene { name:'KDR', entrez:'3791'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'cabozantinib'}) MERGE (g:Gene { name:'KDR', entrez:'3791'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'cabozantinib'}) MERGE (g:Gene { name:'FLT3', entrez:'2322'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'cabozantinib'}) MERGE (g:Gene { name:'FLT3', entrez:'2322'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'cabozantinib'}) MERGE (g:Gene { name:'FLT3', entrez:'2322'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'cabozantinib'}) MERGE (g:Gene { name:'FLT3', entrez:'2322'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'cabozantinib'}) MERGE (g:Gene { name:'AXL', entrez:'558'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'cabozantinib'}) MERGE (g:Gene { name:'AXL', entrez:'558'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'cabozantinib'}) MERGE (g:Gene { name:'AXL', entrez:'558'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'carboplatin'}) MERGE (g:Gene { name:'GSTP1', entrez:'2950'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'carboplatin'}) MERGE (g:Gene { name:'WEE1', entrez:'7465'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'carboplatin'}) MERGE (g:Gene { name:'WEE1', entrez:'7465'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'carboplatin'}) MERGE (g:Gene { name:'WEE1', entrez:'7465'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'carboplatin'}) MERGE (g:Gene { name:'CHEK1', entrez:'1111'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'carboplatin'}) MERGE (g:Gene { name:'CHEK1', entrez:'1111'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'carboplatin'}) MERGE (g:Gene { name:'CHEK1', entrez:'1111'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'carboplatin'}) MERGE (g:Gene { name:'RAD51D', entrez:'5892'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'carboplatin'}) MERGE (g:Gene { name:'RAD51D', entrez:'5892'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'carboplatin'}) MERGE (g:Gene { name:'RAD51D', entrez:'5892'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'carboplatin'}) MERGE (g:Gene { name:'RAD51D', entrez:'5892'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'carboplatin'}) MERGE (g:Gene { name:'RAD51D', entrez:'5892'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'carboplatin'}) MERGE (g:Gene { name:'RAD51D', entrez:'5892'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'carboplatin'}) MERGE (g:Gene { name:'SLC31A1', entrez:'1317'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'carboplatin'}) MERGE (g:Gene { name:'SLC31A1', entrez:'1317'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'carboplatin'}) MERGE (g:Gene { name:'XPC', entrez:'7508'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'carboplatin'}) MERGE (g:Gene { name:'XPC', entrez:'7508'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'carboplatin'}) MERGE (g:Gene { name:'XPC', entrez:'7508'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'carboplatin'}) MERGE (g:Gene { name:'OGG1', entrez:'4968'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'carboplatin'}) MERGE (g:Gene { name:'OGG1', entrez:'4968'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'carboplatin'}) MERGE (g:Gene { name:'TXN', entrez:'7295'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'carboplatin'}) MERGE (g:Gene { name:'POLH', entrez:'5429'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'carboplatin'}) MERGE (g:Gene { name:'POLH', entrez:'5429'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'carboplatin'}) MERGE (g:Gene { name:'POLH', entrez:'5429'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'carboplatin'}) MERGE (g:Gene { name:'BRCA2', entrez:'675'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'carboplatin'}) MERGE (g:Gene { name:'BRCA2', entrez:'675'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'carboplatin'}) MERGE (g:Gene { name:'BRCA2', entrez:'675'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'carboplatin'}) MERGE (g:Gene { name:'BRCA2', entrez:'675'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'carboplatin'}) MERGE (g:Gene { name:'BRCA2', entrez:'675'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'carboplatin'}) MERGE (g:Gene { name:'BRCA2', entrez:'675'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'carboplatin'}) MERGE (g:Gene { name:'BRIP1', entrez:'83990'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'carboplatin'}) MERGE (g:Gene { name:'BRIP1', entrez:'83990'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'carboplatin'}) MERGE (g:Gene { name:'BRIP1', entrez:'83990'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'carboplatin'}) MERGE (g:Gene { name:'BRIP1', entrez:'83990'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# MATCH (d:Drug { name:'carboplatin'}) MERGE (g:Gene { name:'BRIP1', entrez:'83990'}) CREATE UNIQUE (d)-[:TARGETS]->(g)
# ...
# MATCH (g:Gene {name:'MN1', entrez:'4330'}), (a:Aberration { type:'exp', value:'over', gene_entrez:'4330', entity_class:'modifier' }), (d:Drug {name:'doxorubicin'} ) Merge (r:Rule {rulenum:'1006', evidence:'direct', pmid:'http://www.ncbi.nlm.nih.gov/pubmed/22905229', evidence_text:"In vitro murine AML cells that overexpressed MN1 became resistant to treatment with cytarabine and highly resistant to doxorubicin." }) CREATE UNIQUE (r)<-[:IS_PART_OF]-(g) CREATE UNIQUE (r)<-[:IS_PART_OF]-(a) CREATE UNIQUE (r)<-[:IS_PART_OF]-(d)
# MATCH (g:Gene {name:'FOXM1', entrez:'2305'}), (a:Aberration { type:'cnv', value:'gain', gene_entrez:'2305', entity_class:'modifier' }), (d:Drug {name:'doxorubicin'} ) Merge (r:Rule {rulenum:'1007', evidence:'inferred', pmid:'http://www.ncbi.nlm.nih.gov/pubmed/23108394', evidence_text:"Ectopic expression of FOXM1 can increase cell viability and abrogate DSBs sustained by MCF-7 cells following epirubicin, owing to an enhancement in repair efficiency. Conversely, alkaline comet and _H2AX foci formation assays show that Foxm1-null cells are hypersensitive to DNA damage, epirubicin and _-irradiation. " }) CREATE UNIQUE (r)<-[:IS_PART_OF]-(g) CREATE UNIQUE (r)<-[:IS_PART_OF]-(a) CREATE UNIQUE (r)<-[:IS_PART_OF]-(d)
# MATCH (g:Gene {name:'FOXM1', entrez:'2305'}), (a:Aberration { type:'exp', value:'over', gene_entrez:'2305', entity_class:'modifier' }), (d:Drug {name:'doxorubicin'} ) Merge (r:Rule {rulenum:'1008', evidence:'direct', pmid:'http://www.ncbi.nlm.nih.gov/pubmed/23108394', evidence_text:"Ectopic expression of FOXM1 can increase cell viability and abrogate DSBs sustained by MCF-7 cells following epirubicin, owing to an enhancement in repair efficiency. Conversely, alkaline comet and _H2AX foci formation assays show that Foxm1-null cells are hypersensitive to DNA damage, epirubicin and _-irradiation. " }) CREATE UNIQUE (r)<-[:IS_PART_OF]-(g) CREATE UNIQUE (r)<-[:IS_PART_OF]-(a) CREATE UNIQUE (r)<-[:IS_PART_OF]-(d)
# MATCH (g:Gene {name:'DLX4', entrez:'1748'}), (a:Aberration { type:'cnv', value:'gain', gene_entrez:'1748', entity_class:'modifier' }), (d:Drug {name:'doxorubicin'} ) Merge (r:Rule {rulenum:'1009', evidence:'inferred', pmid:'http://www.ncbi.nlm.nih.gov/pubmed/23222298', evidence_text:"Expression of DLX4 significantly reduced sensitivity of MDA-MB-468 cells to doxorubicin (P = 0.005) but did not alter sensitivity to paclitaxel (microtubule disruptor), 5-fluorouracil (pyrimidine analogue), or cyclophosphamide (alkylating agent; Supplementary Table SI). Analysis of breast cancer datasets revealed that TOP2A-high cases that also highly expressed DLX4 responded more poorly to anthracycline-based chemotherapy than TOP2A-high cases that expressed DLX4 at low levels.  Our findings indicate that DLX4 induces TOP2A expression but reduces sensitivity of tumor cells to TOP2 poisons by stimulating Ku-dependent repair of DSBs. These opposing activities of DLX4 could explain why some TOP2A-overexpressing tumors are not highly sensitive to TOP2 poisons." }) CREATE UNIQUE (r)<-[:IS_PART_OF]-(g) CREATE UNIQUE (r)<-[:IS_PART_OF]-(a) CREATE UNIQUE (r)<-[:IS_PART_OF]-(d)
# MATCH (g:Gene {name:'DLX4', entrez:'1748'}), (a:Aberration { type:'exp', value:'over', gene_entrez:'1748', entity_class:'modifier' }), (d:Drug {name:'doxorubicin'} ) Merge (r:Rule {rulenum:'1010', evidence:'direct', pmid:'http://www.ncbi.nlm.nih.gov/pubmed/23222298', evidence_text:"Expression of DLX4 significantly reduced sensitivity of MDA-MB-468 cells to doxorubicin (P = 0.005) but did not alter sensitivity to paclitaxel (microtubule disruptor), 5-fluorouracil (pyrimidine analogue), or cyclophosphamide (alkylating agent; Supplementary Table SI). Analysis of breast cancer datasets revealed that TOP2A-high cases that also highly expressed DLX4 responded more poorly to anthracycline-based chemotherapy than TOP2A-high cases that expressed DLX4 at low levels.  Our findings indicate that DLX4 induces TOP2A expression but reduces sensitivity of tumor cells to TOP2 poisons by stimulating Ku-dependent repair of DSBs. These opposing activities of DLX4 could explain why some TOP2A-overexpressing tumors are not highly sensitive to TOP2 poisons." }) CREATE UNIQUE (r)<-[:IS_PART_OF]-(g) CREATE UNIQUE (r)<-[:IS_PART_OF]-(a) CREATE UNIQUE (r)<-[:IS_PART_OF]-(d)
# MATCH (g:Gene {name:'FASN', entrez:'2194'}), (a:Aberration { type:'cnv', value:'gain', gene_entrez:'2194', entity_class:'modifier' }), (d:Drug {name:'doxorubicin'} ) Merge (r:Rule {rulenum:'1011', evidence:'inferred', pmid:'http://www.ncbi.nlm.nih.gov/pubmed/23613870', evidence_text:"Caveolin-1 (Cav-1), Fatty acid synthase (FASN) and Cytochrome P450 (CYP450) protein levels were elevated in drug resistant cells. Downregulation of these molecules by respective siRNAs and/or by specific pharmacological inhibitors resensitize cells to paclitaxel. Interestingly, these drug resistant cells were also less sensitive to vinblastine, doxorubicin and methotrexate with the exception of cisplatin." }) CREATE UNIQUE (r)<-[:IS_PART_OF]-(g) CREATE UNIQUE (r)<-[:IS_PART_OF]-(a) CREATE UNIQUE (r)<-[:IS_PART_OF]-(d)
# MATCH (g:Gene {name:'FASN', entrez:'2194'}), (a:Aberration { type:'exp', value:'over', gene_entrez:'2194', entity_class:'modifier' }), (d:Drug {name:'doxorubicin'} ) Merge (r:Rule {rulenum:'1012', evidence:'direct', pmid:'http://www.ncbi.nlm.nih.gov/pubmed/23613870', evidence_text:"Caveolin-1 (Cav-1), Fatty acid synthase (FASN) and Cytochrome P450 (CYP450) protein levels were elevated in drug resistant cells. Downregulation of these molecules by respective siRNAs and/or by specific pharmacological inhibitors resensitize cells to paclitaxel. Interestingly, these drug resistant cells were also less sensitive to vinblastine, doxorubicin and methotrexate with the exception of cisplatin." }) CREATE UNIQUE (r)<-[:IS_PART_OF]-(g) CREATE UNIQUE (r)<-[:IS_PART_OF]-(a) CREATE UNIQUE (r)<-[:IS_PART_OF]-(d)
# MATCH (g:Gene {name:'ABCG2', entrez:'9429'}), (a:Aberration { type:'cnv', value:'gain', gene_entrez:'9429', entity_class:'modifier' }), (d:Drug {name:'doxorubicin'} ) Merge (r:Rule {rulenum:'1013', evidence:'inferred', pmid:'http://www.ncbi.nlm.nih.gov/pubmed/24179544', evidence_text:"The Eca109/ABCG2 esophageal cancer cells with ABCG2 gene overexpression were resistant to adriamycin (ADM), daunorubicin (DNR) and mitoxantrone (MIT), which indicated that ABCG2 may be associated with drug resistance in esophageal cancer. " }) CREATE UNIQUE (r)<-[:IS_PART_OF]-(g) CREATE UNIQUE (r)<-[:IS_PART_OF]-(a) CREATE UNIQUE (r)<-[:IS_PART_OF]-(d)
# MATCH (g:Gene {name:'ABCG2', entrez:'9429'}), (a:Aberration { type:'exp', value:'over', gene_entrez:'9429', entity_class:'modifier' }), (d:Drug {name:'doxorubicin'} ) Merge (r:Rule {rulenum:'1014', evidence:'direct', pmid:'http://www.ncbi.nlm.nih.gov/pubmed/24179544', evidence_text:"The Eca109/ABCG2 esophageal cancer cells with ABCG2 gene overexpression were resistant to adriamycin (ADM), daunorubicin (DNR) and mitoxantrone (MIT), which indicated that ABCG2 may be associated with drug resistance in esophageal cancer. " }) CREATE UNIQUE (r)<-[:IS_PART_OF]-(g) CREATE UNIQUE (r)<-[:IS_PART_OF]-(a) CREATE UNIQUE (r)<-[:IS_PART_OF]-(d)
# MATCH (g:Gene {name:'PRKDC', entrez:'5591'}), (a:Aberration { type:'cnv', value:'gain', gene_entrez:'5591', entity_class:'modifier' }), (d:Drug {name:'doxorubicin'} ) Merge (r:Rule {rulenum:'1015', evidence:'inferred', pmid:'http://www.ncbi.nlm.nih.gov/pubmed/9685611', evidence_text:"The overexpression of DNA-PK is thus shown to be a novel cellular adaptation mechanistically contributing to the resistance of cancer cells to the anthracycline drug adriamycin, and as such, may have implications for its therapeutic use." }) CREATE UNIQUE (r)<-[:IS_PART_OF]-(g) CREATE UNIQUE (r)<-[:IS_PART_OF]-(a) CREATE UNIQUE (r)<-[:IS_PART_OF]-(d)
# MATCH (g:Gene {name:'PRKDC', entrez:'5591'}), (a:Aberration { type:'exp', value:'over', gene_entrez:'5591', entity_class:'modifier' }), (d:Drug {name:'doxorubicin'} ) Merge (r:Rule {rulenum:'1016', evidence:'direct', pmid:'http://www.ncbi.nlm.nih.gov/pubmed/9685611', evidence_text:"The overexpression of DNA-PK is thus shown to be a novel cellular adaptation mechanistically contributing to the resistance of cancer cells to the anthracycline drug adriamycin, and as such, may have implications for its therapeutic use." }) CREATE UNIQUE (r)<-[:IS_PART_OF]-(g) CREATE UNIQUE (r)<-[:IS_PART_OF]-(a) CREATE UNIQUE (r)<-[:IS_PART_OF]-(d)
# MATCH (g:Gene {name:'ZNF217', entrez:'7764'}), (a:Aberration { type:'cnv', value:'gain', gene_entrez:'7764', entity_class:'modifier' }), (d:Drug {name:'doxorubicin'} ) Merge (r:Rule {rulenum:'1017', evidence:'inferred', pmid:'http://www.ncbi.nlm.nih.gov/pubmed16203743', evidence_text:"We present evidence that ZNF217 can attenuate apoptotic signals resulting from telomere dysfunction as well as from doxorubicin-induced DNA damage and that silencing ZNF217 with siRNA restores sensitize to doxorubicin." }) CREATE UNIQUE (r)<-[:IS_PART_OF]-(g) CREATE UNIQUE (r)<-[:IS_PART_OF]-(a) CREATE UNIQUE (r)<-[:IS_PART_OF]-(d)
# MATCH (g:Gene {name:'ZNF217', entrez:'7764'}), (a:Aberration { type:'exp', value:'over', gene_entrez:'7764', entity_class:'modifier' }), (d:Drug {name:'doxorubicin'} ) Merge (r:Rule {rulenum:'1018', evidence:'direct', pmid:'http://www.ncbi.nlm.nih.gov/pubmed16203743', evidence_text:"We present evidence that ZNF217 can attenuate apoptotic signals resulting from telomere dysfunction as well as from doxorubicin-induced DNA damage and that silencing ZNF217 with siRNA restores sensitize to doxorubicin." }) CREATE UNIQUE (r)<-[:IS_PART_OF]-(g) CREATE UNIQUE (r)<-[:IS_PART_OF]-(a) CREATE UNIQUE (r)<-[:IS_PART_OF]-(d)
# MATCH (g:Gene {name:'RND3', entrez:'390'}), (a:Aberration { type:'cnv', value:'gain', gene_entrez:'390', entity_class:'modifier' }), (d:Drug {name:'doxorubicin'} ) Merge (r:Rule {rulenum:'1019', evidence:'inferred', pmid:'http://www.ncbi.nlm.nih.gov/pubmed19101510', evidence_text:"Our study demonstrated that RhoE may promote the multidrug resistance phenotype of gastric cancer cells by decreasing the expression of Bax at posttranscriptional level, thus inhibiting vincristine-induced apoptosis. The IC50 values of SGC7901-RhoE cells for ADR, VCR, CDDP, 5-FU, VP-16, MMC were significantly increased compared with those of SGC7901-FLAG cells" }) CREATE UNIQUE (r)<-[:IS_PART_OF]-(g) CREATE UNIQUE (r)<-[:IS_PART_OF]-(a) CREATE UNIQUE (r)<-[:IS_PART_OF]-(d)
# MATCH (g:Gene {name:'RND3', entrez:'390'}), (a:Aberration { type:'exp', value:'over', gene_entrez:'390', entity_class:'modifier' }), (d:Drug {name:'doxorubicin'} ) Merge (r:Rule {rulenum:'1020', evidence:'direct', pmid:'http://www.ncbi.nlm.nih.gov/pubmed19101510', evidence_text:"Our study demonstrated that RhoE may promote the multidrug resistance phenotype of gastric cancer cells by decreasing the expression of Bax at posttranscriptional level, thus inhibiting vincristine-induced apoptosis. The IC50 values of SGC7901-RhoE cells for ADR, VCR, CDDP, 5-FU, VP-16, MMC were significantly increased compared with those of SGC7901-FLAG cells" }) CREATE UNIQUE (r)<-[:IS_PART_OF]-(g) CREATE UNIQUE (r)<-[:IS_PART_OF]-(a) CREATE UNIQUE (r)<-[:IS_PART_OF]-(d)
# MATCH (g:Gene {name:'TP53', entrez:'7157'}), (a:Aberration { type:'exp', value:'under', gene_entrez:'7157', entity_class:'modifier' }), (d:Drug {name:'doxorubicin'} ) Merge (r:Rule {rulenum:'1021', evidence:'direct', pmid:'http://www.ncbi.nlm.nih.gov/pubmed22763759', evidence_text:"The growth-inhibitory activity of vincristine, doxorubicin, carboplatin, etoposide, and temozolomide was significantly impaired by silencing of TP53. In conclusion, these results indicate a potential predictive role of p53 in choroid plexus carcinomas. Alterations of p53 should be taken into account when evaluating the effect of anticancer agents in future clinical trials." }) CREATE UNIQUE (r)<-[:IS_PART_OF]-(g) CREATE UNIQUE (r)<-[:IS_PART_OF]-(a) CREATE UNIQUE (r)<-[:IS_PART_OF]-(d)
# MATCH (g:Gene {name:'TP53', entrez:'7157'}), (a:Aberration { type:'cnv', value:'loss', gene_entrez:'7157', entity_class:'modifier' }), (d:Drug {name:'doxorubicin'} ) Merge (r:Rule {rulenum:'1022', evidence:'inferred', pmid:'http://www.ncbi.nlm.nih.gov/pubmed22763759', evidence_text:"The growth-inhibitory activity of vincristine, doxorubicin, carboplatin, etoposide, and temozolomide was significantly impaired by silencing of TP53. In conclusion, these results indicate a potential predictive role of p53 in choroid plexus carcinomas. Alterations of p53 should be taken into account when evaluating the effect of anticancer agents in future clinical trials." }) CREATE UNIQUE (r)<-[:IS_PART_OF]-(g) CREATE UNIQUE (r)<-[:IS_PART_OF]-(a) CREATE UNIQUE (r)<-[:IS_PART_OF]-(d)
# MATCH (g:Gene {name:'NFKBIA', entrez:'4792'}), (a:Aberration { type:'snv', value:'change', gene_entrez:'4792', entity_class:'modifier' }), (d:Drug {name:'erlotinib'} ) Merge (r:Rule {rulenum:'1023', evidence:'inferred', pmid:'http://www.ncbi.nlm.nih.gov/pubmed/21430781', evidence_text:"Because reduced I_B levels were associated with erlotinib resistance in cell lines and tumour models, we asked if I_B expression correlated with EGFR TKI response in patients with EGFR-mutant lung cancers. Low I_B expression (�_���__�_��_�_���__�_���_�high-NF-_B' activation state) was predictive of worse progression-free survival (Fig. 4c and Supplementary Table 4a) and decreased overall survival (Supplementary Fig. 16a and Supplementary Table 4b). |Annotator Note:SNVs should be loss-of-function and associated with reduced drug sensitivity. However, not all SNVs may result in loss-of-function and reduced drug sensitivity." }) CREATE UNIQUE (r)<-[:IS_PART_OF]-(g) CREATE UNIQUE (r)<-[:IS_PART_OF]-(a) CREATE UNIQUE (r)<-[:IS_PART_OF]-(d)
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-2-6a4304bab4b9> in <module>()
#     109     createAberrations(graph,data)
#     110     createRuleNodes(graph,data)
# --> 111 main()
#
# <ipython-input-2-6a4304bab4b9> in main()
#     108     createGenes(graph,data)
#     109     createAberrations(graph,data)
# --> 110     createRuleNodes(graph,data)
#     111 main()
#
# <ipython-input-2-6a4304bab4b9> in createRuleNodes(graph, data)
#      94                          row["drug"], row_index, row["Evidence"], row["PMID"], row["Evidence Text"])
#      95         print query
# ---> 96         graph.cypher.execute(query)
#      97
#      98
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/py2neo/cypher/core.pyc in execute(self, statement, parameters, **kwparameters)
#     108         if self.transaction_uri:
#     109             tx = CypherTransaction(self.transaction_uri)
# --> 110             tx.append(statement, parameters, **kwparameters)
#     111             results = tx.commit()
#     112             return results[0]
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/py2neo/cypher/core.pyc in append(self, statement, parameters, **kwparameters)
#     220         self.__assert_unfinished()
#     221
# --> 222         s = ustr(statement)
#     223         p = {}
#     224
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/py2neo/util.pyc in ustr(s, encoding)
#     208         """
#     209         if isinstance(s, str):
# --> 210             return s.decode(encoding)
#     211         else:
#     212             return unicode(s)
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/encodings/utf_8.pyc in decode(input, errors)
#      14
#      15 def decode(input, errors='strict'):
# ---> 16     return codecs.utf_8_decode(input, errors, True)
#      17
#      18 class IncrementalEncoder(codecs.IncrementalEncoder):
#
# UnicodeDecodeError: 'utf8' codec can't decode byte 0xcc in position 513: invalid continuation byte
